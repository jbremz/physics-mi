# %% [markdown]
# # Hand-crafted finetune + playing with y-offset
#
# I'm going to try and understand whether the model in experiment 7 was stuck in a local minima by playing with the y-offset i.e. the bias term in the hidden layer.

# %%
import torch
from torch import nn
from torch.optim import Adam
from matplotlib import pyplot as plt
from matplotlib import cm
import pandas as pd
from tqdm.notebook import tqdm
import numpy as np

from physics_mi.utils import set_all_seeds
from physics_mi.net import print_model_params

# %%
# seed = np.random.randint(1, 2**32 - 1)
seed = 2813536937  # found as training mode 3 through trial and error
set_all_seeds(seed)
print(seed)
# Out:
# 2813536937

# %% [markdown]
# ## Model
#
# Keeping this extremely simple

# %%
class LinearLayer(nn.Module):
    def __init__(self, in_feats, out_feats, use_act=True, *args, **kwargs) -> None:
        super().__init__(*args, **kwargs)
        self.linear = nn.Linear(in_feats, out_feats)
        if use_act:
            self.act = nn.ReLU()
        self.use_act = use_act

    def forward(self, x):
        x = self.linear(x)
        if self.use_act:
            x = self.act(x)
        return x


class Net(nn.Module):
    def __init__(self, use_act=True, dim=32, *args, **kwargs) -> None:
        super().__init__(*args, **kwargs)
        self.layers = nn.Sequential(LinearLayer(2, dim, use_act=use_act), LinearLayer(dim, 1, use_act=False))

    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ## Data
#
# I'm returning to the original uniformly distributed in Y data.

# %%
eps = 0.5

Y = torch.rand(10000)
X = torch.empty(10000, 2)
X[:, 0] = Y / (torch.rand(10000) * (1 - eps) + eps)
X[:, 1] = Y / X[:, 0]

# need to randomly swap x1 and x2 so that they're identically distributed - can do this because their product is commutative
mask = torch.rand(10000) < 0.5
swap_vals = X[:, 0][mask]
X[:, 0][mask] = X[:, 1][mask]
X[:, 1][mask] = swap_vals

assert torch.allclose(X[:, 0] * X[:, 1], Y)

Y = Y[:, None]
X.shape, Y.shape
# Out:
# (torch.Size([10000, 2]), torch.Size([10000, 1]))

# %%
fig, ax = plt.subplots()

ax.hist(X[:, 0], alpha=0.5, density=True, label="mass")
ax.hist(X[:, 1], alpha=0.5, density=True, label="acceleration")
ax.hist(Y[:, 0], alpha=0.5, density=True, label="force")
ax.legend()

# %%
s_inds = np.random.permutation(range(X.shape[0]))  # shuffled indices

X_train = X[s_inds[:8000]]
Y_train = Y[s_inds[:8000]]
X_valid = X[s_inds[8000:]]
Y_valid = Y[s_inds[8000:]]

X_train.shape, Y_train.shape, X_valid.shape, Y_valid.shape
# Out:
# (torch.Size([8000, 2]),
#  torch.Size([8000, 1]),
#  torch.Size([2000, 2]),
#  torch.Size([2000, 1]))

# %% [markdown]
# ## Load model

# %%
model = Net(use_act=True, dim=2)
model.load_state_dict(torch.load("models/e-6.pth"))
# Out:
# <All keys matched successfully>

# %%
model
# Out:
# Net(
#   (layers): Sequential(
#     (0): LinearLayer(
#       (linear): Linear(in_features=2, out_features=2, bias=True)
#       (act): ReLU()
#     )
#     (1): LinearLayer(
#       (linear): Linear(in_features=2, out_features=1, bias=True)
#     )
#   )
# )

# %%
model.layers[0].linear.bias
# Out:
# Parameter containing:
# tensor([0.0000, 1.4142], requires_grad=True)

# %% [markdown]
# Just going to push it up a bit to see if we get a better loss / the optimisation moves the bias around again.

# %%
model.layers[0].linear.bias = nn.Parameter(torch.tensor([-0.0023, 1.6139]))
model.layers[0].linear.bias
# Out:
# Parameter containing:
# tensor([-0.0023,  1.6139], requires_grad=True)

# %%
print_model_params(model)
# Out:
# layers.0.linear.weight
#  tensor([[-0.7071,  0.7071],
#         [-0.7071, -0.7071]])
#
# layers.0.linear.bias
#  tensor([-0.0023,  1.6139])
#
# layers.1.linear.weight
#  tensor([[-0.5000, -0.7071]])
#
# layers.1.linear.bias
#  tensor([1.])

# %% [markdown]
# ## Training
#
# I'll just do full gradient descent to keep things simple.

# %%
N = 4000  # number of epochs

loss_func = nn.MSELoss()
optimiser = Adam(model.parameters(), lr=1e-4)
log = []

for i in tqdm(range(N)):
    log_sample = {}

    # Training update
    model.train()
    model.zero_grad()
    Y_hat = model(X_train)
    loss = loss_func(Y_hat, Y_train)
    log_sample["train_loss"] = float(loss.detach())
    loss.backward()
    optimiser.step()

    # Validation set
    model.eval()
    Y_hat = model(X_valid)
    loss = loss_func(Y_hat, Y_valid)
    log_sample["valid_loss"] = float(loss.detach())

    log.append(log_sample)

df = pd.DataFrame(log)
# Out:
#   0%|          | 0/4000 [00:00<?, ?it/s]

# %% [markdown]
# ## Results

# %%
def plot_loss(train_loss, valid_loss):
    _, ax = plt.subplots()

    ax.plot(train_loss, label="train")
    ax.plot(valid_loss, label="valid")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend()


def get_preds(model):
    model.eval()

    with torch.inference_mode():
        out = model(X_valid)

    y_preds = out.flatten().numpy()
    y_targs = Y_valid.flatten().numpy()

    return y_preds, y_targs


def get_valid_loss(model, loss_func):
    model.eval()

    with torch.inference_mode():
        out = model(X_valid)

    return loss_func(out, Y_valid)


def plot_results(y_preds, y_targs):
    _, ax = plt.subplots()

    ax.scatter(y_preds, y_targs, s=4, label="predictions")
    ax.plot(y_targs, y_targs, color="salmon", ls="--", lw=0.5, label="perfect accuracy")
    ax.set(xlabel="y_preds", ylabel="y_targs")
    ax.legend()

# %%
plot_loss(df["train_loss"], df["valid_loss"])

# %%
y_preds, y_targs = get_preds(model)

# %%
get_valid_loss(model, loss_func)
# Out:
# tensor(0.0015)

# %%
plot_results(y_preds, y_targs)

# %% [markdown]
# Looking much more like our previous plot now although the loss is still higher than in experiment 4 so we may have found a more local minimum.

# %% [markdown]
# ## Introspection

# %% [markdown]
# ### Inspect intermediate values
#
# Going to go operation by operation to see if I can see what's going on.
#
# input ($\rightarrow$ prebias_preacts $\rightarrow$ preacts $\rightarrow$ acts) ($\rightarrow$ prebias $\rightarrow$ output)
#
# (with the layers grouped in brackets)

# %%
SD = model.state_dict()

# %%
from collections import OrderedDict


def model_breakdown(x1, x2, print_steps=True, return_steps=False):
    x1, x2 = float(x1), float(x2)

    x = torch.tensor([[x1, x2]]).T
    prebias_preacts = torch.matmul(SD["layers.0.linear.weight"], x)
    preacts = prebias_preacts[:, 0] + SD["layers.0.linear.bias"]
    acts = torch.nn.functional.relu(preacts)
    prebias = torch.matmul(SD["layers.1.linear.weight"], acts)
    output = prebias + SD["layers.1.linear.bias"]

    if print_steps:
        print("Input:", "\n", x, "\n")

        print("================ Layer 0 ================", "\n")
        print("Weight:", "\n", SD["layers.0.linear.weight"], "\n")
        print("Result:", "\n", prebias_preacts, "\n")
        print("Bias:", "\n", SD["layers.0.linear.bias"], "\n")
        print("Result:", "\n", preacts, "\n")
        print("Activations:", "\n", acts, "\n")

        print("================ Layer 1 ================", "\n")
        print("Weight:", "\n", SD["layers.1.linear.weight"], "\n")
        print("Result:", "\n", prebias, "\n")
        print("Bias:", "\n", SD["layers.1.linear.bias"], "\n")
        print("Output:", "\n", output, "\n")

        print(f"y_true = {x1*x2:.3f}")

    if return_steps:
        return prebias_preacts, preacts, acts, prebias, output


def plot_model_breakdown(
    x1,
    x2,
    ax=None,
    legend=True,
    color=None,
    product_color=False,
    point_selector={
        "input": True,
        "prebias_preacts": False,
        "preacts": False,
        "acts": False,
        "prebias": False,
        "output": True,
    },
):
    if not ax:
        fig = plt.figure()
        ax = plt.axes()

    input = (x1, x2)

    if not color and product_color:
        val = x1 * x2
        cmap = cm.plasma
        val = val**0.5  # looks better on the unit square with some scaling
        color = cmap(val)

    prebias_preacts, preacts, acts, prebias, output = model_breakdown(*input, print_steps=False, return_steps=True)

    x = OrderedDict()
    x["input"] = input
    x["prebias_preacts"] = prebias_preacts.flatten().tolist()
    x["preacts"] = preacts.flatten().tolist()
    x["acts"] = acts.flatten().tolist()
    x["prebias"] = [float(prebias), 0]
    x["output"] = [float(output), 0]

    markers = {}
    markers["input"] = "v"
    markers["prebias_preacts"] = "o"
    markers["preacts"] = "o"
    markers["acts"] = "o"
    markers["prebias"] = "o"
    markers["output"] = "x"

    for point_name, point in x.items():
        if point_selector[point_name]:
            ax.scatter(*point, alpha=1.0, label=point_name, color=color, marker=markers[point_name])

    x_arr = np.array(list(x.values()))

    ax.plot(*x_arr.T, lw=0.5, color=color)
    ax.set(xlabel="component 0", ylabel="component 1")
    if legend:
        ax.legend()


def get_colors(N):
    cmap = plt.get_cmap("turbo", N)
    colors = []
    for i in range(cmap.N):
        colors.append(cmap(i))
    return colors

# %%
model_breakdown(0.75, 1.0)
# Out:
# Input:
#  tensor([[0.7500],
#         [1.0000]])
#
# ================ Layer 0 ================
#
# Weight:
#  tensor([[-0.7496,  0.6446],
#         [-0.6469, -0.8784]])
#
# Result:
#  tensor([[ 0.0824],
#         [-1.3636]])
#
# Bias:
#  tensor([-0.0371,  1.8354])
#
# Result:
#  tensor([0.0453, 0.4718])
#
# Activations:
#  tensor([0.0453, 0.4718])
#
# ================ Layer 1 ================
#
# Weight:
#  tensor([[-0.4133, -0.8965]])
#
# Result:
#  tensor([-0.4417])
#
# Bias:
#  tensor([1.1978])
#
# Output:
#  tensor([0.7560])
#
# y_true = 0.750

# %%
fig, axes = plt.subplots(5, 1, figsize=(10, 40))

N = 5
pairs = np.concatenate(np.stack(np.meshgrid(np.linspace(0, 1, N), np.linspace(0, 1, N))).T)

# cols = get_colors(len(pairs))

subsets = [
    {
        "input": True,
        "prebias_preacts": False,
        "preacts": False,
        "acts": False,
        "prebias": False,
        "output": True,
    },
    {
        "input": False,
        "prebias_preacts": True,
        "preacts": False,
        "acts": False,
        "prebias": False,
        "output": True,
    },
    {
        "input": False,
        "prebias_preacts": False,
        "preacts": True,
        "acts": False,
        "prebias": False,
        "output": True,
    },
    {
        "input": False,
        "prebias_preacts": False,
        "preacts": False,
        "acts": True,
        "prebias": False,
        "output": True,
    },
    {
        "input": False,
        "prebias_preacts": False,
        "preacts": False,
        "acts": False,
        "prebias": True,
        "output": True,
    },
]

titles = ["input", "prebias_preacts", "preacts", "acts", "prebias"]

for ax, subset, title in zip(axes.flatten(), subsets, titles):
    plot_model_breakdown(*pairs[0], ax, product_color=True, point_selector=subset)
    for pair in pairs[1:]:
        plot_model_breakdown(*pair, ax, legend=False, product_color=True, point_selector=subset)
    ax.set_title(title)
    ax.set_aspect("equal")

# %% [markdown]
# Hmm it's interesting just from playing around with the hidden layer bias that it doesn't seem to be optimised in training all that much, suggesting we're _easily_ finding a local minimum. I suppose (again) this comes from the fact that we're starting from a largely pre-optimised network and not using any learning rate annealing or related training strategies.
#
# Anyway, this gives a lower loss, suggesting that the y-component of the bias term in the hidden layer does help.
#
# ### Understanding skew mechanism more
#
# I have this idea to plot some loss curves by manually adjusting the skew of the hidden linear layer. The problem is, that I'd then also need to optimise the downstream elements again to give a fair value of the loss. I suppose this is possible but would need a more automated training setup (entirely possible) because I'd want to sample the skew quite densely.
#
# My idea is that as I modify the skew parameter I can produce a nice loss graph to show the local minimum. Maybe this will trivially appear (as we've been optimising the network for lower loss anyway) but it might be interesting to isolate its effect on the loss?
#
# Anyway, I'll give some more thought to this.
#
# ### Mode equivalence
#
# I think my next step will instead be to explore other trained examples of the network to see whether I can find whether what I have understood can generalise at least for the "optimal" family of trained examples that I think I might have identified.
#
# One thing I am expecting to see are rotated algorithms that use the ReLU projection on the "x" component (as the problem is symmetrical).

# %%
# torch.save(model.state_dict(), 'models/e-8.pth')
